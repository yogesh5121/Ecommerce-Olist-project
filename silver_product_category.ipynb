# %%
df_product_cat = spark.read.table("olist.bronze.olist_product_category")

df_product_cat.display()

# %%
df_product_cat.write.format("delta").mode("overwrite").saveAsTable("olist.silver.olist_product_category")
